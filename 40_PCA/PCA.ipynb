# %% [markdown]
# ### PCA (Principal Component Analysis)

# %%
1+1
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cpuinfo as ci

# %%
print(ci.get_cpu_info())
# Out:
# {'python_version': '3.12.7.final.0 (64 bit)', 'cpuinfo_version': [9, 0, 0], 'cpuinfo_version_string': '9.0.0', 'arch': 'X86_64', 'bits': 64, 'count': 12, 'arch_string_raw': 'AMD64', 'vendor_id_raw': 'GenuineIntel', 'brand_raw': '13th Gen Intel(R) Core(TM) i7-1355U', 'hz_actual_friendly': '1.7000 GHz', 'hz_actual': [1700000000, 0], 'l2_cache_size': 6815744, 'stepping': 3, 'model': 186, 'family': 6, 'l3_cache_size': 12582912, 'hz_advertised_friendly': '2.6110 GHz', 'hz_advertised': [2611000000, 0], 'flags': ['3dnow', '3dnowprefetch', 'abm', 'acpi', 'adx', 'aes', 'apic', 'avx', 'avx2', 'bmi1', 'bmi2', 'clflush', 'clflushopt', 'clwb', 'cmov', 'cx16', 'cx8', 'de', 'dts', 'erms', 'est', 'f16c', 'fma', 'fpu', 'fxsr', 'gfni', 'ht', 'hypervisor', 'ia64', 'intel_pt', 'invpcid', 'lahf_lm', 'mca', 'mce', 'mmx', 'monitor', 'movbe', 'msr', 'mtrr', 'osxsave', 'pae', 'pat', 'pbe', 'pcid', 'pclmulqdq', 'pdcm', 'pge', 'pni', 'popcnt', 'pse', 'pse36', 'rdpid', 'rdrnd', 'rdseed', 'sep', 'serial', 'sha',
# ...
