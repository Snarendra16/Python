# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
words=["running","ran","runs","easily","fairly"]

# %%
Stemmer=PorterStemmer()

# %%
for word in words:
    print(f"{word} -----> {Stemmer.stem(word)}")
# Out:
# running -----> run
# ran -----> ran
# runs -----> run
# easily -----> easili
# fairly -----> fairli

# %% [markdown]
# This is a disadvantage of Porterstemming irrelevent meaning of words generate

# %%
from nltk.stem import RegexpStemmer
from nltk.stem import SnowballStemmer

reg=RegexpStemmer('ing$ |s$|e$|able$', min=4)
snow=SnowballStemmer("english")

# %%
for word in words:
    print(f"{word} --> {reg.stem(word)}")
# Out:
# running --> running
# ran --> ran
# runs --> run
# easily --> easily
# fairly --> fairly

# %%
for word in words:
    print(f"{word} --> {snow.stem(word)}")
# Out:
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fair
