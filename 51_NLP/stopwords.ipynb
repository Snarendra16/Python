# %% [markdown]
# ## Stopwords

# %%
1+1
# Out:
# 2

# %%
corpus="""Success in life is rarely the result of one single dramatic moment, but rather the accumulation of small and consistent efforts that a person repeats every day with patience and determination. When someone decides that they want to improve their skills, learn new ideas, and explore unfamiliar challenges, they slowly begin to transform their potential into real capability. At first the progress may appear invisible, and many people will feel that the work they are doing is not producing immediate results. However, the remarkable truth about growth is that persistence quietly compounds over time, much like interest in a long-term investment. A person who continues to read, practice, experiment, and reflect will gradually build knowledge and confidence that others may never see until the moment when that preparation suddenly becomes visible as achievement. The world often celebrates the final result, but it is the quiet discipline behind the scenes that truly shapes success. Therefore, anyone who wishes to achieve meaningful goals must learn to embrace effort, remain curious about the unknown, and continue moving forward even when progress feels slow and uncertain."""

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stemmer=PorterStemmer()

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
from nltk.tokenize import sent_tokenize
sentences=nltk.sent_tokenize(corpus)

# %%
for i in range(len(sentences)):
    nltk.word_tokenize(sentences[i])
    words=[stemmer.stem(word) for word in nltk.word_tokenize(sentences[i]) if word not in stopwords.words('english')]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['success life rare result one singl dramat moment , rather accumul small consist effort person repeat everi day patienc determin .',
#  'when someon decid want improv skill , learn new idea , explor unfamiliar challeng , slowli begin transform potenti real capabl .',
#  'at first progress may appear invis , mani peopl feel work produc immedi result .',
#  'howev , remark truth growth persist quietli compound time , much like interest long-term invest .',
#  'a person continu read , practic , experi , reflect gradual build knowledg confid other may never see moment prepar suddenli becom visibl achiev .',
#  'the world often celebr final result , quiet disciplin behind scene truli shape success .',
#  'therefor , anyon wish achiev meaning goal must learn embrac effort , remain curiou unknown , continu move forward even progress feel slow uncertain .']
